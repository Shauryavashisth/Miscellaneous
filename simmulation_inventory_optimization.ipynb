# %%
import simpy
import numpy as np
import pandas as pd

class stocking_facility(object):
    def __init__(self, env, node_id, is_source, initial_inv, ROP, base_stock,
                 upstream, hist_demand, default_lead_time, lead_time_delay):
        self.env = env
        self.name = "node" + str(node_id)
        self.isSource = is_source
        self.on_hand_inventory = initial_inv
        self.inventory_position = initial_inv
        self.ROP = ROP
        self.baseStock = base_stock
        self.upstream = upstream
        self.histDemand = hist_demand
        self.defaultLeadTime = default_lead_time
        self.leadTimeDelay = lead_time_delay
        self.order_q = []
        self.totalDemand = 0.0
        self.totalShipped = 0.0
        self.serviceLevel = 0.0
        self.avgOnHand = 0.0
        self.onHandMon = []
        self.demandMon = []
        self.ordersPlaced = []
        self.shipmentsFulfilled = []
        self.shipmentsDict = {}
        self.remaining_order = 0
        self.shipment = 0
        self.shipment_serve_cust = 0
        self.demand = 0
        self.active_prepare_replenishment = 0
        self.order_check_inv = 0
        self.dd_hist = []

        self.env.process(self.check_inventory())
        self.env.process(self.prepare_replenishment())
        self.env.process(self.serve_customer())

    def check_inventory(self):
        while True:
            yield self.env.timeout(1.0)
            if self.inventory_position <= 1.05 * self.ROP:  # add 5% to avoid rounding issues
                order_qty = self.baseStock - self.on_hand_inventory
                order = {"orderQty": order_qty, "requester": self}
                self.upstream.order_q.append(order)
                self.inventory_position += order_qty
                self.order_check_inv = order_qty
                # self.ordersPlaced.append((self.env.now, order_qty))  # Track when the order is placed

    def prepare_replenishment(self):
        while True:
            if len(self.order_q) > 0:
                self.active_prepare_replenishment = 1
                order = self.order_q.pop(0)
                shipment = min(order["orderQty"], self.on_hand_inventory)
                self.shipment = shipment
                if not self.isSource:
                    self.inventory_position -= shipment
                    self.on_hand_inventory -= shipment
                remaining_order = order["orderQty"] - shipment
                self.remaining_order = remaining_order
                if remaining_order:
                    while not self.on_hand_inventory >= remaining_order:
                        yield self.env.timeout(1.0)
                    if not self.isSource:
                        self.inventory_position -= remaining_order
                        self.on_hand_inventory -= remaining_order
                # Schedule the shipment with the correct lead time
                self.env.process(self.ship(order["orderQty"], order["requester"]))
                # self.shipmentsFulfilled.append((self.env.now, order["orderQty"]))  # Track fulfillment time
                # self.shipmentsDict[self.env.now + self.defaultLeadTime] = order["orderQty"]
            else:
                yield self.env.timeout(1.0)

    def ship(self, qty, requester):
        lead_time = requester.defaultLeadTime  # Set the expected lead time
        yield self.env.timeout(lead_time)
        requester.on_hand_inventory += qty
        # requester.inventory_position += qty  # Update inventory position when the shipment arrives

    def serve_customer(self):
        while True:
            self.onHandMon.append(self.on_hand_inventory)
            yield self.env.timeout(1.0)
            demand = np.random.choice(self.histDemand, replace=True)
            self.demand = demand
            self.totalDemand += demand
            shipment = min(demand, self.on_hand_inventory)
            self.shipment_serve_cust = shipment
            self.totalShipped += shipment
            self.on_hand_inventory -= shipment
            self.inventory_position -= shipment
            self.demandMon.append(demand)

def simulate_network(seedinit, num_nodes, network, initial_inv, ROP, base_stock, demand, lead_time, lead_time_delay, time_units):
    env = simpy.Environment()
    np.random.seed(seedinit)
    nodes = []
    data_records = []  # List to collect data for Excel
   
    for i in range(num_nodes):
        if i == 0:
            s = stocking_facility(env, i, 1, initial_inv[i], ROP[i], base_stock[i], None, np.zeros(100), lead_time[i], lead_time_delay)
        else:
            for j in range(num_nodes):
                if network[j][i] == 1:
                    s = stocking_facility(env, i, 0, initial_inv[i], ROP[i], base_stock[i], nodes[j], demand[:, i - 1], lead_time[i], lead_time_delay)
                    break
        nodes.append(s)

    # Run the simulation and print values after each time unit
    for t in range(time_units):
        env.run(until=t+1)
        print(f"\nTime Unit {t+1}:")
        for node in nodes:
            print(
                  f"DEMAND: {node.demand}, "
                  f"Node {node.name} - On-hand Inventory: {node.on_hand_inventory}, "
                  f"Inventory Position: {node.inventory_position}, "
                  f"ROP: {node.ROP}, "
                  f"Base Stock: {node.baseStock}, "
                  f"order_check_inv: {node.order_check_inv},"
                  f"active_prepare_replenishment: {node.active_prepare_replenishment}, "
                  f"Shipment: {node.shipment}, "
                  f"Remaining Order: {node.remaining_order}, "
                  f"Shipment_serve_cust: {node.shipment_serve_cust}, "
                  f"Total Demand: {node.totalDemand}, "
                  f"Total Shipped: {node.totalShipped}",
                  f"Orders Placed: {node.ordersPlaced}")
                  # f"Shipments Fulfilled: {node.shipmentsFulfilled}"
   
    return nodes

# Simulation parameters
seedinit = 42
num_nodes = 3
network = [[0, 1, 1], [0, 0, 0], [0, 0, 0]]
ROP = [0, 400, 250]
base_stock = [10000, 600, 400]
initial_inv = [10000, 500, 300]
demand = np.array([[10, 20, 15, 25, 30], [5, 10, 7, 12, 8]]).T
lead_time = [0, 3, 3]
lead_time_delay = [0, 0, 0]
time_units = 30

print(f"Initial Inventory: {initial_inv}")
print(f"ROP: {ROP}")
print(f"Base Stock: {base_stock}")
print(f"Lead Time: {lead_time}")
nodes = simulate_network(seedinit, num_nodes, network, initial_inv, ROP, base_stock, demand, lead_time, lead_time_delay, time_units)
# Out:
# Initial Inventory: [10000, 500, 300]
# ROP: [0, 400, 250]
# Base Stock: [10000, 600, 400]
# Lead Time: [0, 3, 3]
#
# Time Unit 1:
# DEMAND: 0, Node node0 - On-hand Inventory: 10000, Inventory Position: 10000, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 0, Node node1 - On-hand Inventory: 500, Inventory Position: 500, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 0, Node node2 - On-hand Inventory: 300, Inventory Position: 300, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
#
# Time Unit 2:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 470, Inventory Position: 470, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 30.0, Total Shipped: 30.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 293, Inventory Position: 293, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 7.0, Total Shipped: 7.0 Orders Placed: []
#
# Time Unit 3:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 440, Inventory Position: 440, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 60.0, Total Shipped: 60.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 285, Inventory Position: 285, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 15.0, Total Shipped: 15.0 Orders Placed: []
#
# Time Unit 4:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 425, Inventory Position: 425, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 75.0, Total Shipped: 75.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 278, Inventory Position: 278, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 22.0, Total Shipped: 22.0 Orders Placed: []
#
# Time Unit 5:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 395, Inventory Position: 395, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 105.0, Total Shipped: 105.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 266, Inventory Position: 266, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 34.0, Total Shipped: 34.0 Orders Placed: []
#
# Time Unit 6:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 380, Inventory Position: 585, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 120.0, Total Shipped: 120.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 258, Inventory Position: 258, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 42.0, Total Shipped: 42.0 Orders Placed: []
#
# Time Unit 7:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 205, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 355, Inventory Position: 560, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 145.0, Total Shipped: 145.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 248, Inventory Position: 390, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 52.0, Total Shipped: 52.0 Orders Placed: []
#
# Time Unit 8:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 330, Inventory Position: 535, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 170.0, Total Shipped: 170.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 240, Inventory Position: 382, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 60.0, Total Shipped: 60.0 Orders Placed: []
#
# Time Unit 9:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 305, Inventory Position: 510, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 195.0, Total Shipped: 195.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 230, Inventory Position: 372, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 70.0, Total Shipped: 70.0 Orders Placed: []
#
# Time Unit 10:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 480, Inventory Position: 480, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 225.0, Total Shipped: 225.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 218, Inventory Position: 360, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 82.0, Total Shipped: 82.0 Orders Placed: []
#
# Time Unit 11:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 470, Inventory Position: 470, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 235.0, Total Shipped: 235.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 353, Inventory Position: 353, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 89.0, Total Shipped: 89.0 Orders Placed: []
#
# Time Unit 12:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 450, Inventory Position: 450, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 255.0, Total Shipped: 255.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 341, Inventory Position: 341, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 101.0, Total Shipped: 101.0 Orders Placed: []
#
# Time Unit 13:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 435, Inventory Position: 435, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 270.0, Total Shipped: 270.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 329, Inventory Position: 329, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 113.0, Total Shipped: 113.0 Orders Placed: []
#
# Time Unit 14:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 410, Inventory Position: 410, ROP: 400, Base Stock: 600, order_check_inv: 205,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 295.0, Total Shipped: 295.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 324, Inventory Position: 324, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 118.0, Total Shipped: 118.0 Orders Placed: []
#
# Time Unit 15:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 142, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 380, Inventory Position: 570, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 325.0, Total Shipped: 325.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 317, Inventory Position: 317, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 125.0, Total Shipped: 125.0 Orders Placed: []
#
# Time Unit 16:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 350, Inventory Position: 540, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 355.0, Total Shipped: 355.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 312, Inventory Position: 312, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 130.0, Total Shipped: 130.0 Orders Placed: []
#
# Time Unit 17:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 330, Inventory Position: 520, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 375.0, Total Shipped: 375.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 300, Inventory Position: 300, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 142.0, Total Shipped: 142.0 Orders Placed: []
#
# Time Unit 18:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 305, Inventory Position: 495, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 400.0, Total Shipped: 400.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 290, Inventory Position: 290, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 152.0, Total Shipped: 152.0 Orders Placed: []
#
# Time Unit 19:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 475, Inventory Position: 475, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 420.0, Total Shipped: 420.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 282, Inventory Position: 282, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 160.0, Total Shipped: 160.0 Orders Placed: []
#
# Time Unit 20:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 450, Inventory Position: 450, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 445.0, Total Shipped: 445.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 270, Inventory Position: 270, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 172.0, Total Shipped: 172.0 Orders Placed: []
#
# Time Unit 21:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 425, Inventory Position: 425, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 470.0, Total Shipped: 470.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 262, Inventory Position: 262, ROP: 250, Base Stock: 400, order_check_inv: 142,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 180.0, Total Shipped: 180.0 Orders Placed: []
#
# Time Unit 22:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 410, Inventory Position: 410, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 485.0, Total Shipped: 485.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 257, Inventory Position: 395, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 185.0, Total Shipped: 185.0 Orders Placed: []
#
# Time Unit 23:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 138, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 390, Inventory Position: 580, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 505.0, Total Shipped: 505.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 245, Inventory Position: 383, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 197.0, Total Shipped: 197.0 Orders Placed: []
#
# Time Unit 24:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 370, Inventory Position: 560, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 525.0, Total Shipped: 525.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 233, Inventory Position: 371, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 209.0, Total Shipped: 209.0 Orders Placed: []
#
# Time Unit 25:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 340, Inventory Position: 530, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 555.0, Total Shipped: 555.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 223, Inventory Position: 361, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 219.0, Total Shipped: 219.0 Orders Placed: []
#
# Time Unit 26:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 315, Inventory Position: 505, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 580.0, Total Shipped: 580.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 351, Inventory Position: 351, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 229.0, Total Shipped: 229.0 Orders Placed: []
#
# Time Unit 27:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 480, Inventory Position: 480, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 605.0, Total Shipped: 605.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 339, Inventory Position: 339, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 241.0, Total Shipped: 241.0 Orders Placed: []
#
# Time Unit 28:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 450, Inventory Position: 450, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 635.0, Total Shipped: 635.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 331, Inventory Position: 331, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 249.0, Total Shipped: 249.0 Orders Placed: []
#
# Time Unit 29:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 420, Inventory Position: 420, ROP: 400, Base Stock: 600, order_check_inv: 190,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 665.0, Total Shipped: 665.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 321, Inventory Position: 321, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 259.0, Total Shipped: 259.0 Orders Placed: []
#
# Time Unit 30:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 190, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 395, Inventory Position: 575, ROP: 400, Base Stock: 600, order_check_inv: 180,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 690.0, Total Shipped: 690.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 309, Inventory Position: 309, ROP: 250, Base Stock: 400, order_check_inv: 138,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 271.0, Total Shipped: 271.0 Orders Placed: []

# %%
# nodes[1].demandMon

# %%
# Define the supply chain network
num_nodes = 6
network = np.zeros((num_nodes, num_nodes))
network[0, 1] = 1
network[1, 2] = 1
network[1, 3] = 1
network[3, 4] = 1
network[3, 5] = 1


ROP = [0, 400, 250, 150, 200, 180]
base_stock = [10000, 600, 400, 900, 600, 450]
initial_inv = [10000, 500, 300, 810, 540, 360]
demand = np.array([
    [10, 20, 15, 25, 30],
    [5, 10, 7, 12, 8],
    [0, 0, 0, 0, 0],
    [6, 12, 8, 15, 10],
    [4, 9, 6, 10, 7],
]).T
lead_time = [0, 3, 3, 3, 3, 3]
lead_time_delay = [0, 0, 0, 0, 0, 0]
time_units = 365

print(f"Initial Inventory: {initial_inv}")
print(f"ROP: {ROP}")
print(f"Base Stock: {base_stock}")
print(f"Lead Time: {lead_time}")
nodes = simulate_network(seedinit, num_nodes, network, initial_inv, ROP, base_stock, demand, lead_time, lead_time_delay, time_units)
# Out:
# Initial Inventory: [10000, 500, 300, 810, 540, 360]
# ROP: [0, 400, 250, 150, 200, 180]
# Base Stock: [10000, 600, 400, 900, 600, 450]
# Lead Time: [0, 3, 3, 3, 3, 3]
#
# Time Unit 1:
# DEMAND: 0, Node node0 - On-hand Inventory: 10000, Inventory Position: 10000, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 0, Node node1 - On-hand Inventory: 500, Inventory Position: 500, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 0, Node node2 - On-hand Inventory: 300, Inventory Position: 300, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 0, Node node4 - On-hand Inventory: 540, Inventory Position: 540, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 0, Node node5 - On-hand Inventory: 360, Inventory Position: 360, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
#
# Time Unit 2:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 470, Inventory Position: 470, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 30.0, Total Shipped: 30.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 293, Inventory Position: 293, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 7.0, Total Shipped: 7.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node4 - On-hand Inventory: 530, Inventory Position: 530, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 10.0, Total Shipped: 10.0 Orders Placed: []
# DEMAND: 9, Node node5 - On-hand Inventory: 351, Inventory Position: 351, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 9, Total Demand: 9.0, Total Shipped: 9.0 Orders Placed: []
#
# Time Unit 3:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 455, Inventory Position: 455, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 45.0, Total Shipped: 45.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 286, Inventory Position: 286, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 14.0, Total Shipped: 14.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 515, Inventory Position: 515, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 25.0, Total Shipped: 25.0 Orders Placed: []
# DEMAND: 6, Node node5 - On-hand Inventory: 345, Inventory Position: 345, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 15.0, Total Shipped: 15.0 Orders Placed: []
#
# Time Unit 4:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 425, Inventory Position: 425, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 75.0, Total Shipped: 75.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 276, Inventory Position: 276, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 24.0, Total Shipped: 24.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 503, Inventory Position: 503, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 37.0, Total Shipped: 37.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 335, Inventory Position: 335, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 25.0, Total Shipped: 25.0 Orders Placed: []
#
# Time Unit 5:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 415, Inventory Position: 415, ROP: 400, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 85.0, Total Shipped: 85.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 264, Inventory Position: 264, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 36.0, Total Shipped: 36.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node4 - On-hand Inventory: 493, Inventory Position: 493, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 47.0, Total Shipped: 47.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 325, Inventory Position: 325, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 35.0, Total Shipped: 35.0 Orders Placed: []
#
# Time Unit 6:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 405, Inventory Position: 590, ROP: 400, Base Stock: 600, order_check_inv: 185,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 95.0, Total Shipped: 95.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 257, Inventory Position: 257, ROP: 250, Base Stock: 400, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 43.0, Total Shipped: 43.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 481, Inventory Position: 481, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 59.0, Total Shipped: 59.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 315, Inventory Position: 315, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 45.0, Total Shipped: 45.0 Orders Placed: []
#
# Time Unit 7:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 185, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 390, Inventory Position: 575, ROP: 400, Base Stock: 600, order_check_inv: 185,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 110.0, Total Shipped: 110.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 245, Inventory Position: 388, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 55.0, Total Shipped: 55.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 475, Inventory Position: 475, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 65.0, Total Shipped: 65.0 Orders Placed: []
# DEMAND: 6, Node node5 - On-hand Inventory: 309, Inventory Position: 309, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 51.0, Total Shipped: 51.0 Orders Placed: []
#
# Time Unit 8:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 185, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 217, Inventory Position: 402, ROP: 400, Base Stock: 600, order_check_inv: 185,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 140.0, Total Shipped: 140.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 240, Inventory Position: 383, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 60.0, Total Shipped: 60.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 460, Inventory Position: 460, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 80.0, Total Shipped: 80.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 305, Inventory Position: 305, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 55.0, Total Shipped: 55.0 Orders Placed: []
#
# Time Unit 9:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 185, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 197, Inventory Position: 765, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 160.0, Total Shipped: 160.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 230, Inventory Position: 373, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 70.0, Total Shipped: 70.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 448, Inventory Position: 448, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 92.0, Total Shipped: 92.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 298, Inventory Position: 298, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 62.0, Total Shipped: 62.0 Orders Placed: []
#
# Time Unit 10:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 357, Inventory Position: 740, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 185.0, Total Shipped: 185.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 218, Inventory Position: 361, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 82.0, Total Shipped: 82.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 433, Inventory Position: 433, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 107.0, Total Shipped: 107.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 291, Inventory Position: 291, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 69.0, Total Shipped: 69.0 Orders Placed: []
#
# Time Unit 11:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 342, Inventory Position: 725, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 200.0, Total Shipped: 200.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 356, Inventory Position: 356, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 87.0, Total Shipped: 87.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 421, Inventory Position: 421, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 119.0, Total Shipped: 119.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 281, Inventory Position: 281, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 79.0, Total Shipped: 79.0 Orders Placed: []
#
# Time Unit 12:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 322, Inventory Position: 705, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 220.0, Total Shipped: 220.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 344, Inventory Position: 344, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 99.0, Total Shipped: 99.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 409, Inventory Position: 409, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 131.0, Total Shipped: 131.0 Orders Placed: []
# DEMAND: 9, Node node5 - On-hand Inventory: 272, Inventory Position: 272, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 9, Total Demand: 88.0, Total Shipped: 88.0 Orders Placed: []
#
# Time Unit 13:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 685, Inventory Position: 685, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 240.0, Total Shipped: 240.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 334, Inventory Position: 334, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 109.0, Total Shipped: 109.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 394, Inventory Position: 394, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 146.0, Total Shipped: 146.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 268, Inventory Position: 268, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 92.0, Total Shipped: 92.0 Orders Placed: []
#
# Time Unit 14:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 655, Inventory Position: 655, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 270.0, Total Shipped: 270.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 326, Inventory Position: 326, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 117.0, Total Shipped: 117.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node4 - On-hand Inventory: 384, Inventory Position: 384, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 156.0, Total Shipped: 156.0 Orders Placed: []
# DEMAND: 9, Node node5 - On-hand Inventory: 259, Inventory Position: 259, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 9, Total Demand: 101.0, Total Shipped: 101.0 Orders Placed: []
#
# Time Unit 15:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 630, Inventory Position: 630, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 295.0, Total Shipped: 295.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 314, Inventory Position: 314, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 129.0, Total Shipped: 129.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node4 - On-hand Inventory: 374, Inventory Position: 374, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 166.0, Total Shipped: 166.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 255, Inventory Position: 255, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 105.0, Total Shipped: 105.0 Orders Placed: []
#
# Time Unit 16:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 600, Inventory Position: 600, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 325.0, Total Shipped: 325.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 309, Inventory Position: 309, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 134.0, Total Shipped: 134.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 368, Inventory Position: 368, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 172.0, Total Shipped: 172.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 251, Inventory Position: 251, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 109.0, Total Shipped: 109.0 Orders Placed: []
#
# Time Unit 17:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 585, Inventory Position: 585, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 340.0, Total Shipped: 340.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 302, Inventory Position: 302, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 141.0, Total Shipped: 141.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 8, Node node4 - On-hand Inventory: 360, Inventory Position: 360, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 180.0, Total Shipped: 180.0 Orders Placed: []
# DEMAND: 6, Node node5 - On-hand Inventory: 245, Inventory Position: 245, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 115.0, Total Shipped: 115.0 Orders Placed: []
#
# Time Unit 18:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 570, Inventory Position: 570, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 355.0, Total Shipped: 355.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 294, Inventory Position: 294, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 149.0, Total Shipped: 149.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 348, Inventory Position: 348, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 192.0, Total Shipped: 192.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 241, Inventory Position: 241, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 119.0, Total Shipped: 119.0 Orders Placed: []
#
# Time Unit 19:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 560, Inventory Position: 560, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 365.0, Total Shipped: 365.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 282, Inventory Position: 282, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 161.0, Total Shipped: 161.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 342, Inventory Position: 342, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 198.0, Total Shipped: 198.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 234, Inventory Position: 234, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 126.0, Total Shipped: 126.0 Orders Placed: []
#
# Time Unit 20:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 535, Inventory Position: 535, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 390.0, Total Shipped: 390.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 275, Inventory Position: 275, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 168.0, Total Shipped: 168.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 336, Inventory Position: 336, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 204.0, Total Shipped: 204.0 Orders Placed: []
# DEMAND: 6, Node node5 - On-hand Inventory: 228, Inventory Position: 228, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 132.0, Total Shipped: 132.0 Orders Placed: []
#
# Time Unit 21:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 520, Inventory Position: 520, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 405.0, Total Shipped: 405.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 270, Inventory Position: 270, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 173.0, Total Shipped: 173.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 324, Inventory Position: 324, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 216.0, Total Shipped: 216.0 Orders Placed: []
# DEMAND: 6, Node node5 - On-hand Inventory: 222, Inventory Position: 222, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 138.0, Total Shipped: 138.0 Orders Placed: []
#
# Time Unit 22:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 500, Inventory Position: 500, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 425.0, Total Shipped: 425.0 Orders Placed: []
# DEMAND: 10, Node node2 - On-hand Inventory: 260, Inventory Position: 260, ROP: 250, Base Stock: 400, order_check_inv: 143,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 183.0, Total Shipped: 183.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node4 - On-hand Inventory: 314, Inventory Position: 314, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 226.0, Total Shipped: 226.0 Orders Placed: []
# DEMAND: 6, Node node5 - On-hand Inventory: 216, Inventory Position: 216, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 144.0, Total Shipped: 144.0 Orders Placed: []
#
# Time Unit 23:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 490, Inventory Position: 490, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 143, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 435.0, Total Shipped: 435.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 248, Inventory Position: 388, ROP: 250, Base Stock: 400, order_check_inv: 140,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 195.0, Total Shipped: 195.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 299, Inventory Position: 299, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 241.0, Total Shipped: 241.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 209, Inventory Position: 209, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 151.0, Total Shipped: 151.0 Orders Placed: []
#
# Time Unit 24:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 320, Inventory Position: 320, ROP: 400, Base Stock: 600, order_check_inv: 383,active_prepare_replenishment: 1, Shipment: 140, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 465.0, Total Shipped: 465.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 241, Inventory Position: 381, ROP: 250, Base Stock: 400, order_check_inv: 140,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 202.0, Total Shipped: 202.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 284, Inventory Position: 284, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 256.0, Total Shipped: 256.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 202, Inventory Position: 202, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 158.0, Total Shipped: 158.0 Orders Placed: []
#
# Time Unit 25:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 383, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node1 - On-hand Inventory: 305, Inventory Position: 585, ROP: 400, Base Stock: 600, order_check_inv: 280,active_prepare_replenishment: 1, Shipment: 140, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 480.0, Total Shipped: 480.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 234, Inventory Position: 374, ROP: 250, Base Stock: 400, order_check_inv: 140,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 209.0, Total Shipped: 209.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 272, Inventory Position: 272, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 268.0, Total Shipped: 268.0 Orders Placed: []
# DEMAND: 9, Node node5 - On-hand Inventory: 193, Inventory Position: 193, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 9, Total Demand: 167.0, Total Shipped: 167.0 Orders Placed: []
#
# Time Unit 26:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 280, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 295, Inventory Position: 575, ROP: 400, Base Stock: 600, order_check_inv: 280,active_prepare_replenishment: 1, Shipment: 140, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 490.0, Total Shipped: 490.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 226, Inventory Position: 366, ROP: 250, Base Stock: 400, order_check_inv: 140,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 217.0, Total Shipped: 217.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 257, Inventory Position: 257, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 283.0, Total Shipped: 283.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 183, Inventory Position: 183, ROP: 180, Base Stock: 450, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 177.0, Total Shipped: 177.0 Orders Placed: []
#
# Time Unit 27:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 280, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 270, Inventory Position: 550, ROP: 400, Base Stock: 600, order_check_inv: 280,active_prepare_replenishment: 1, Shipment: 140, Remaining Order: 0, Shipment_serve_cust: 25, Total Demand: 515.0, Total Shipped: 515.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 359, Inventory Position: 359, ROP: 250, Base Stock: 400, order_check_inv: 140,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 224.0, Total Shipped: 224.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 810, Inventory Position: 810, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 242, Inventory Position: 242, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 298.0, Total Shipped: 298.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 179, Inventory Position: 446, ROP: 180, Base Stock: 450, order_check_inv: 267,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 181.0, Total Shipped: 181.0 Orders Placed: []
#
# Time Unit 28:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 280, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 260, Inventory Position: 540, ROP: 400, Base Stock: 600, order_check_inv: 280,active_prepare_replenishment: 1, Shipment: 140, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 525.0, Total Shipped: 525.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 354, Inventory Position: 354, ROP: 250, Base Stock: 400, order_check_inv: 140,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 229.0, Total Shipped: 229.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 543, Inventory Position: 543, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 267, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 8, Node node4 - On-hand Inventory: 234, Inventory Position: 234, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 306.0, Total Shipped: 306.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 175, Inventory Position: 442, ROP: 180, Base Stock: 450, order_check_inv: 267,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 185.0, Total Shipped: 185.0 Orders Placed: []
#
# Time Unit 29:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 280, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 530, Inventory Position: 530, ROP: 400, Base Stock: 600, order_check_inv: 280,active_prepare_replenishment: 1, Shipment: 140, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 535.0, Total Shipped: 535.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 347, Inventory Position: 347, ROP: 250, Base Stock: 400, order_check_inv: 140,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 236.0, Total Shipped: 236.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 543, Inventory Position: 543, ROP: 150, Base Stock: 900, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 267, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 228, Inventory Position: 228, ROP: 200, Base Stock: 600, order_check_inv: 0,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 312.0, Total Shipped: 312.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 168, Inventory Position: 435, ROP: 180, Base Stock: 450, order_check_inv: 267,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 192.0, Total Shipped: 192.0 Orders Placed: []
#
# Time Unit 30:
# ...
# DEMAND: 0, Node node3 - On-hand Inventory: 60, Inventory Position: 900, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 399, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 520, Inventory Position: 520, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 3576.0, Total Shipped: 3576.0 Orders Placed: []
# DEMAND: 6, Node node5 - On-hand Inventory: 224, Inventory Position: 224, ROP: 180, Base Stock: 450, order_check_inv: 269,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 2522.0, Total Shipped: 2522.0 Orders Placed: []
#
# Time Unit 357:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 600, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 260, Inventory Position: 575, ROP: 400, Base Stock: 600, order_check_inv: 315,active_prepare_replenishment: 1, Shipment: 545, Remaining Order: 295, Shipment_serve_cust: 25, Total Demand: 7045.0, Total Shipped: 6385.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 272, Inventory Position: 272, ROP: 250, Base Stock: 400, order_check_inv: 139,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 3022.0, Total Shipped: 3022.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 60, Inventory Position: 900, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 399, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 505, Inventory Position: 505, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 3591.0, Total Shipped: 3591.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 217, Inventory Position: 217, ROP: 180, Base Stock: 450, order_check_inv: 269,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 2529.0, Total Shipped: 2529.0 Orders Placed: []
#
# Time Unit 358:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 315, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 230, Inventory Position: 545, ROP: 400, Base Stock: 600, order_check_inv: 315,active_prepare_replenishment: 1, Shipment: 545, Remaining Order: 295, Shipment_serve_cust: 30, Total Demand: 7075.0, Total Shipped: 6415.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 267, Inventory Position: 267, ROP: 250, Base Stock: 400, order_check_inv: 139,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 3027.0, Total Shipped: 3027.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 60, Inventory Position: 900, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 399, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 499, Inventory Position: 499, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 3597.0, Total Shipped: 3597.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 207, Inventory Position: 207, ROP: 180, Base Stock: 450, order_check_inv: 269,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 2539.0, Total Shipped: 2539.0 Orders Placed: []
#
# Time Unit 359:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 315, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 205, Inventory Position: 520, ROP: 400, Base Stock: 600, order_check_inv: 315,active_prepare_replenishment: 1, Shipment: 545, Remaining Order: 295, Shipment_serve_cust: 25, Total Demand: 7100.0, Total Shipped: 6440.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 255, Inventory Position: 255, ROP: 250, Base Stock: 400, order_check_inv: 139,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 3039.0, Total Shipped: 3039.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 900, Inventory Position: 900, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 399, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node4 - On-hand Inventory: 489, Inventory Position: 489, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 3607.0, Total Shipped: 3607.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 197, Inventory Position: 197, ROP: 180, Base Stock: 450, order_check_inv: 269,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 2549.0, Total Shipped: 2549.0 Orders Placed: []
#
# Time Unit 360:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 315, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 25, Node node1 - On-hand Inventory: 180, Inventory Position: 495, ROP: 400, Base Stock: 600, order_check_inv: 315,active_prepare_replenishment: 1, Shipment: 545, Remaining Order: 295, Shipment_serve_cust: 25, Total Demand: 7125.0, Total Shipped: 6465.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 243, Inventory Position: 388, ROP: 250, Base Stock: 400, order_check_inv: 145,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 3051.0, Total Shipped: 3051.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 900, Inventory Position: 900, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 399, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 6, Node node4 - On-hand Inventory: 483, Inventory Position: 483, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 6, Total Demand: 3613.0, Total Shipped: 3613.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 190, Inventory Position: 190, ROP: 180, Base Stock: 450, order_check_inv: 269,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 2556.0, Total Shipped: 2556.0 Orders Placed: []
#
# Time Unit 361:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 315, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 330, Inventory Position: 330, ROP: 400, Base Stock: 600, order_check_inv: 315,active_prepare_replenishment: 1, Shipment: 145, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 7145.0, Total Shipped: 6485.0 Orders Placed: []
# DEMAND: 5, Node node2 - On-hand Inventory: 238, Inventory Position: 383, ROP: 250, Base Stock: 400, order_check_inv: 145,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 5, Total Demand: 3056.0, Total Shipped: 3056.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 900, Inventory Position: 900, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 399, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 468, Inventory Position: 468, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 3628.0, Total Shipped: 3628.0 Orders Placed: []
# DEMAND: 10, Node node5 - On-hand Inventory: 180, Inventory Position: 180, ROP: 180, Base Stock: 450, order_check_inv: 269,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 2566.0, Total Shipped: 2566.0 Orders Placed: []
#
# Time Unit 362:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 315, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 30, Node node1 - On-hand Inventory: 300, Inventory Position: 570, ROP: 400, Base Stock: 600, order_check_inv: 270,active_prepare_replenishment: 1, Shipment: 145, Remaining Order: 0, Shipment_serve_cust: 30, Total Demand: 7175.0, Total Shipped: 6515.0 Orders Placed: []
# DEMAND: 12, Node node2 - On-hand Inventory: 226, Inventory Position: 371, ROP: 250, Base Stock: 400, order_check_inv: 145,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 3068.0, Total Shipped: 3068.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 900, Inventory Position: 900, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 399, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 12, Node node4 - On-hand Inventory: 456, Inventory Position: 456, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 12, Total Demand: 3640.0, Total Shipped: 3640.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 173, Inventory Position: 443, ROP: 180, Base Stock: 450, order_check_inv: 270,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 2573.0, Total Shipped: 2573.0 Orders Placed: []
#
# Time Unit 363:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 270, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 290, Inventory Position: 560, ROP: 400, Base Stock: 600, order_check_inv: 270,active_prepare_replenishment: 1, Shipment: 145, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 7185.0, Total Shipped: 6525.0 Orders Placed: []
# DEMAND: 8, Node node2 - On-hand Inventory: 218, Inventory Position: 363, ROP: 250, Base Stock: 400, order_check_inv: 145,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 3076.0, Total Shipped: 3076.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 630, Inventory Position: 630, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 270, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 8, Node node4 - On-hand Inventory: 448, Inventory Position: 448, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 8, Total Demand: 3648.0, Total Shipped: 3648.0 Orders Placed: []
# DEMAND: 4, Node node5 - On-hand Inventory: 169, Inventory Position: 439, ROP: 180, Base Stock: 450, order_check_inv: 270,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 4, Total Demand: 2577.0, Total Shipped: 2577.0 Orders Placed: []
#
# Time Unit 364:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 270, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 10, Node node1 - On-hand Inventory: 280, Inventory Position: 550, ROP: 400, Base Stock: 600, order_check_inv: 270,active_prepare_replenishment: 1, Shipment: 145, Remaining Order: 0, Shipment_serve_cust: 10, Total Demand: 7195.0, Total Shipped: 6535.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 356, Inventory Position: 356, ROP: 250, Base Stock: 400, order_check_inv: 145,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 3083.0, Total Shipped: 3083.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 630, Inventory Position: 630, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 270, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 433, Inventory Position: 433, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 3663.0, Total Shipped: 3663.0 Orders Placed: []
# DEMAND: 9, Node node5 - On-hand Inventory: 160, Inventory Position: 430, ROP: 180, Base Stock: 450, order_check_inv: 270,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 9, Total Demand: 2586.0, Total Shipped: 2586.0 Orders Placed: []
#
# Time Unit 365:
# DEMAND: 0.0, Node node0 - On-hand Inventory: 10000.0, Inventory Position: 10000.0, ROP: 0, Base Stock: 10000, order_check_inv: 0,active_prepare_replenishment: 1, Shipment: 270, Remaining Order: 0, Shipment_serve_cust: 0.0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 20, Node node1 - On-hand Inventory: 260, Inventory Position: 530, ROP: 400, Base Stock: 600, order_check_inv: 270,active_prepare_replenishment: 1, Shipment: 145, Remaining Order: 0, Shipment_serve_cust: 20, Total Demand: 7215.0, Total Shipped: 6555.0 Orders Placed: []
# DEMAND: 7, Node node2 - On-hand Inventory: 349, Inventory Position: 349, ROP: 250, Base Stock: 400, order_check_inv: 145,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 3090.0, Total Shipped: 3090.0 Orders Placed: []
# DEMAND: 0, Node node3 - On-hand Inventory: 630, Inventory Position: 630, ROP: 150, Base Stock: 900, order_check_inv: 840,active_prepare_replenishment: 1, Shipment: 270, Remaining Order: 0, Shipment_serve_cust: 0, Total Demand: 0.0, Total Shipped: 0.0 Orders Placed: []
# DEMAND: 15, Node node4 - On-hand Inventory: 418, Inventory Position: 418, ROP: 200, Base Stock: 600, order_check_inv: 399,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 15, Total Demand: 3678.0, Total Shipped: 3678.0 Orders Placed: []
# DEMAND: 7, Node node5 - On-hand Inventory: 153, Inventory Position: 423, ROP: 180, Base Stock: 450, order_check_inv: 270,active_prepare_replenishment: 0, Shipment: 0, Remaining Order: 0, Shipment_serve_cust: 7, Total Demand: 2593.0, Total Shipped: 2593.0 Orders Placed: []

# %%
# pd.DataFrame({"Node 0":nodes[0].demandMon,
#               "Node 1":nodes[1].demandMon,
#               "Node 2":nodes[2].demandMon,
#               "Node 3":nodes[3].demandMon,
#               "Node 4":nodes[4].demandMon,
#               "Node 5":nodes[5].demandMon}).to_csv("demand_by_numpy.csv")
